# %%
#使用自己的IBMQ帳號
import qiskit as Q
#輸入API
Q.IBMQ.enable_account('9eacd7290c36819ccce35fe32140ae3c5ef276f4b950dc2d97564a0c4399147530fcc08247fcbd0507c17a83f6767d48be1d6184aa3a0118103893ae2daba175')
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from qiskit import *
from qiskit import QuantumCircuit, assemble, Aer
from qiskit.providers.aer import QasmSimulator
from math import pi, sqrt, sin, cos
from qiskit.visualization import plot_bloch_multivector, plot_histogram
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os,sys
from collections import Counter
import pandas as pd

# %%
simulator = QasmSimulator()
params= 4/4*pi
def vqe_ansatz_1(params):
    q = QuantumRegister(5)
    c = ClassicalRegister(5)
    ansatz = QuantumCircuit(q,c)
    #GHZ-like state
    ansatz.h(0)
    ansatz.cx(0,1)
    ansatz.cx(1,2)
    ansatz.cx(2,3)
    ansatz.cx(3,4)
    ansatz.rz(params,q[0])
    return ansatz

# %%
sample_shots = 1024
def expval(params):
    def partial(params):
        # XXXYY
        vqe= vqe_ansatz_1(params)
        vqe.sdg(3)
        vqe.sdg(4)
        vqe.h(0)
        vqe.h(1)
        vqe.h(2)
        vqe.h(3)
        vqe.h(4)
        vqe.measure([0],[0])
        vqe.measure([1],[1])
        vqe.measure([2],[2])
        vqe.measure([3],[3])
        vqe.measure([4],[4])
    
        # Compile and execute
        # use real quantum computer
        provider = Q.IBMQ.get_provider(hub='ibm-q', group='open', project='main')
        qcomp = provider.get_backend('ibmq_manila') #called real quantum computer
        # calculation
        job_qasm = execute(vqe, backend = qcomp, shots=sample_shots)
        result_sim = job_qasm.result().get_counts()
        # Calculate expectation
        P_0=(result_sim.get('00000',0)/sample_shots)+(result_sim.get('00011',0)/sample_shots)
        +(result_sim.get('00101',0)/sample_shots)+(result_sim.get('00110',0)/sample_shots)
        +(result_sim.get('01001',0)/sample_shots)+(result_sim.get('01010',0)/sample_shots)
        +(result_sim.get('01100',0)/sample_shots)+(result_sim.get('01111',0)/sample_shots)
        +(result_sim.get('10001',0)/sample_shots)+(result_sim.get('10010',0)/sample_shots)
        +(result_sim.get('10100',0)/sample_shots)+(result_sim.get('10111',0)/sample_shots)
        +(result_sim.get('11000',0)/sample_shots)+(result_sim.get('11011',0)/sample_shots)
        +(result_sim.get('11101',0)/sample_shots)+(result_sim.get('11110',0)/sample_shots)
        P_1=(result_sim.get('00001',0)/sample_shots)+(result_sim.get('00010',0)/sample_shots)
        +(result_sim.get('00100',0)/sample_shots)+(result_sim.get('00111',0)/sample_shots)
        +(result_sim.get('01000',0)/sample_shots)+(result_sim.get('01011',0)/sample_shots)
        +(result_sim.get('01101',0)/sample_shots)+(result_sim.get('01110',0)/sample_shots)
        +(result_sim.get('10000',0)/sample_shots)+(result_sim.get('10011',0)/sample_shots)
        +(result_sim.get('10101',0)/sample_shots)+(result_sim.get('10110',0)/sample_shots)
        +(result_sim.get('11001',0)/sample_shots)+(result_sim.get('11010',0)/sample_shots)
        +(result_sim.get('11100',0)/sample_shots)+(result_sim.get('11111',0)/sample_shots)
        XXXYY = P_0-P_1
    
        #XXXXX
        vqe= vqe_ansatz_1(params)
        vqe.h(0)
        vqe.h(1)
        vqe.h(2)
        vqe.h(3)
        vqe.h(4)
        vqe.measure([0],[0])
        vqe.measure([1],[1])
        vqe.measure([2],[2])
        vqe.measure([3],[3])
        vqe.measure([4],[4])
        
        # Compile and execute
        # use real quantum computer
        provider = Q.IBMQ.get_provider(hub='ibm-q', group='open', project='main')
        qcomp = provider.get_backend('ibmq_manila') #called real quantum computer
        # calculation
        job_qasm = execute(vqe, backend = qcomp, shots=sample_shots)
        result_sim = job_qasm.result().get_counts()
        # Calculate expectation
        P_0=(result_sim.get('00000',0)/sample_shots)+(result_sim.get('00011',0)/sample_shots)
        +(result_sim.get('00101',0)/sample_shots)+(result_sim.get('00110',0)/sample_shots)
        +(result_sim.get('01001',0)/sample_shots)+(result_sim.get('01010',0)/sample_shots)
        +(result_sim.get('01100',0)/sample_shots)+(result_sim.get('01111',0)/sample_shots)
        +(result_sim.get('10001',0)/sample_shots)+(result_sim.get('10010',0)/sample_shots)
        +(result_sim.get('10100',0)/sample_shots)+(result_sim.get('10111',0)/sample_shots)
        +(result_sim.get('11000',0)/sample_shots)+(result_sim.get('11011',0)/sample_shots)
        +(result_sim.get('11101',0)/sample_shots)+(result_sim.get('11110',0)/sample_shots)
        P_1=(result_sim.get('00001',0)/sample_shots)+(result_sim.get('00010',0)/sample_shots)
        +(result_sim.get('00100',0)/sample_shots)+(result_sim.get('00111',0)/sample_shots)
        +(result_sim.get('01000',0)/sample_shots)+(result_sim.get('01011',0)/sample_shots)
        +(result_sim.get('01101',0)/sample_shots)+(result_sim.get('01110',0)/sample_shots)
        +(result_sim.get('10000',0)/sample_shots)+(result_sim.get('10011',0)/sample_shots)
        +(result_sim.get('10101',0)/sample_shots)+(result_sim.get('10110',0)/sample_shots)
        +(result_sim.get('11001',0)/sample_shots)+(result_sim.get('11010',0)/sample_shots)
        +(result_sim.get('11100',0)/sample_shots)+(result_sim.get('11111',0)/sample_shots)
        XXXXX = P_0-P_1
    
        #XYYYY
        vqe= vqe_ansatz_1(params)
        vqe.sdg(1)
        vqe.sdg(2)
        vqe.sdg(3)
        vqe.sdg(4)
        vqe.h(0)
        vqe.h(1)
        vqe.h(2)
        vqe.h(3)
        vqe.h(4)
        vqe.measure([0],[0])
        vqe.measure([1],[1])
        vqe.measure([2],[2])
        vqe.measure([3],[3])
        vqe.measure([4],[4])
    
        # Compile and execute
        # use real quantum computer
        provider = Q.IBMQ.get_provider(hub='ibm-q', group='open', project='main')
        qcomp = provider.get_backend('ibmq_manila') #called real quantum computer
        # calculation
        job_qasm = execute(vqe, backend = qcomp, shots=sample_shots)
        result_sim = job_qasm.result().get_counts()
        # Calculate expectation
        P_0=(result_sim.get('00000',0)/sample_shots)+(result_sim.get('00011',0)/sample_shots)
        +(result_sim.get('00101',0)/sample_shots)+(result_sim.get('00110',0)/sample_shots)
        +(result_sim.get('01001',0)/sample_shots)+(result_sim.get('01010',0)/sample_shots)
        +(result_sim.get('01100',0)/sample_shots)+(result_sim.get('01111',0)/sample_shots)
        +(result_sim.get('10001',0)/sample_shots)+(result_sim.get('10010',0)/sample_shots)
        +(result_sim.get('10100',0)/sample_shots)+(result_sim.get('10111',0)/sample_shots)
        +(result_sim.get('11000',0)/sample_shots)+(result_sim.get('11011',0)/sample_shots)
        +(result_sim.get('11101',0)/sample_shots)+(result_sim.get('11110',0)/sample_shots)
        P_1=(result_sim.get('00001',0)/sample_shots)+(result_sim.get('00010',0)/sample_shots)
        +(result_sim.get('00100',0)/sample_shots)+(result_sim.get('00111',0)/sample_shots)
        +(result_sim.get('01000',0)/sample_shots)+(result_sim.get('01011',0)/sample_shots)
        +(result_sim.get('01101',0)/sample_shots)+(result_sim.get('01110',0)/sample_shots)
        +(result_sim.get('10000',0)/sample_shots)+(result_sim.get('10011',0)/sample_shots)
        +(result_sim.get('10101',0)/sample_shots)+(result_sim.get('10110',0)/sample_shots)
        +(result_sim.get('11001',0)/sample_shots)+(result_sim.get('11010',0)/sample_shots)
        +(result_sim.get('11100',0)/sample_shots)+(result_sim.get('11111',0)/sample_shots)
        XYYYY = P_0-P_1
    
        #XXYYY
        vqe= vqe_ansatz_1(params)
        vqe.sdg(2)
        vqe.sdg(3)
        vqe.sdg(4)
        vqe.h(0)
        vqe.h(1)
        vqe.h(2)
        vqe.h(3)
        vqe.h(4)
        vqe.measure([0],[0])
        vqe.measure([1],[1])
        vqe.measure([2],[2])
        vqe.measure([3],[3])
        vqe.measure([4],[4])
    
        # Compile and execute
        # use real quantum computer
        provider = Q.IBMQ.get_provider(hub='ibm-q', group='open', project='main')
        qcomp = provider.get_backend('ibmq_manila') #called real quantum computer
        # calculation
        job_qasm = execute(vqe, backend = qcomp, shots=sample_shots)
        result_sim = job_qasm.result().get_counts()
        # Calculate expectation
        P_0=(result_sim.get('00000',0)/sample_shots)+(result_sim.get('00011',0)/sample_shots)
        +(result_sim.get('00101',0)/sample_shots)+(result_sim.get('00110',0)/sample_shots)
        +(result_sim.get('01001',0)/sample_shots)+(result_sim.get('01010',0)/sample_shots)
        +(result_sim.get('01100',0)/sample_shots)+(result_sim.get('01111',0)/sample_shots)
        +(result_sim.get('10001',0)/sample_shots)+(result_sim.get('10010',0)/sample_shots)
        +(result_sim.get('10100',0)/sample_shots)+(result_sim.get('10111',0)/sample_shots)
        +(result_sim.get('11000',0)/sample_shots)+(result_sim.get('11011',0)/sample_shots)
        +(result_sim.get('11101',0)/sample_shots)+(result_sim.get('11110',0)/sample_shots)
        P_1=(result_sim.get('00001',0)/sample_shots)+(result_sim.get('00010',0)/sample_shots)
        +(result_sim.get('00100',0)/sample_shots)+(result_sim.get('00111',0)/sample_shots)
        +(result_sim.get('01000',0)/sample_shots)+(result_sim.get('01011',0)/sample_shots)
        +(result_sim.get('01101',0)/sample_shots)+(result_sim.get('01110',0)/sample_shots)
        +(result_sim.get('10000',0)/sample_shots)+(result_sim.get('10011',0)/sample_shots)
        +(result_sim.get('10101',0)/sample_shots)+(result_sim.get('10110',0)/sample_shots)
        +(result_sim.get('11001',0)/sample_shots)+(result_sim.get('11010',0)/sample_shots)
        +(result_sim.get('11100',0)/sample_shots)+(result_sim.get('11111',0)/sample_shots)
        XXYYY = P_0-P_1
        
        # YYYYY
        vqe= vqe_ansatz_1(params)
        vqe.sdg(0)
        vqe.sdg(1)
        vqe.sdg(2)
        vqe.sdg(3)
        vqe.sdg(4)
        vqe.h(0)
        vqe.h(1)
        vqe.h(2)
        vqe.h(3)
        vqe.h(4)
        vqe.measure([0],[0])
        vqe.measure([1],[1])
        vqe.measure([2],[2])
        vqe.measure([3],[3])
        vqe.measure([4],[4])
    
        # Compile and execute
        # use real quantum computer
        provider = Q.IBMQ.get_provider(hub='ibm-q', group='open', project='main')
        qcomp = provider.get_backend('ibmq_manila') #called real quantum computer
        # calculation
        job_qasm = execute(vqe, backend = qcomp, shots=sample_shots)
        result_sim = job_qasm.result().get_counts()
        # Calculate expectation
        P_0=(result_sim.get('00000',0)/sample_shots)+(result_sim.get('00011',0)/sample_shots)
        +(result_sim.get('00101',0)/sample_shots)+(result_sim.get('00110',0)/sample_shots)
        +(result_sim.get('01001',0)/sample_shots)+(result_sim.get('01010',0)/sample_shots)
        +(result_sim.get('01100',0)/sample_shots)+(result_sim.get('01111',0)/sample_shots)
        +(result_sim.get('10001',0)/sample_shots)+(result_sim.get('10010',0)/sample_shots)
        +(result_sim.get('10100',0)/sample_shots)+(result_sim.get('10111',0)/sample_shots)
        +(result_sim.get('11000',0)/sample_shots)+(result_sim.get('11011',0)/sample_shots)
        +(result_sim.get('11101',0)/sample_shots)+(result_sim.get('11110',0)/sample_shots)
        P_1=(result_sim.get('00001',0)/sample_shots)+(result_sim.get('00010',0)/sample_shots)
        +(result_sim.get('00100',0)/sample_shots)+(result_sim.get('00111',0)/sample_shots)
        +(result_sim.get('01000',0)/sample_shots)+(result_sim.get('01011',0)/sample_shots)
        +(result_sim.get('01101',0)/sample_shots)+(result_sim.get('01110',0)/sample_shots)
        +(result_sim.get('10000',0)/sample_shots)+(result_sim.get('10011',0)/sample_shots)
        +(result_sim.get('10101',0)/sample_shots)+(result_sim.get('10110',0)/sample_shots)
        +(result_sim.get('11001',0)/sample_shots)+(result_sim.get('11010',0)/sample_shots)
        +(result_sim.get('11100',0)/sample_shots)+(result_sim.get('11111',0)/sample_shots)
        YYYYY = P_0-P_1
        
        #XXXXY
        vqe= vqe_ansatz_1(params)
        vqe.sdg(4)
        vqe.h(0)
        vqe.h(1)
        vqe.h(2)
        vqe.h(3)
        vqe.h(4)
        vqe.measure([0],[0])
        vqe.measure([1],[1])
        vqe.measure([2],[2])
        vqe.measure([3],[3])
        vqe.measure([4],[4])
        
        # Compile and execute
        # use real quantum computer
        provider = Q.IBMQ.get_provider(hub='ibm-q', group='open', project='main')
        qcomp = provider.get_backend('ibmq_manila') #called real quantum computer
        # calculation
        job_qasm = execute(vqe, backend = qcomp, shots=sample_shots)
        result_sim = job_qasm.result().get_counts()
        # Calculate expectation
        P_0=(result_sim.get('00000',0)/sample_shots)+(result_sim.get('00011',0)/sample_shots)
        +(result_sim.get('00101',0)/sample_shots)+(result_sim.get('00110',0)/sample_shots)
        +(result_sim.get('01001',0)/sample_shots)+(result_sim.get('01010',0)/sample_shots)
        +(result_sim.get('01100',0)/sample_shots)+(result_sim.get('01111',0)/sample_shots)
        +(result_sim.get('10001',0)/sample_shots)+(result_sim.get('10010',0)/sample_shots)
        +(result_sim.get('10100',0)/sample_shots)+(result_sim.get('10111',0)/sample_shots)
        +(result_sim.get('11000',0)/sample_shots)+(result_sim.get('11011',0)/sample_shots)
        +(result_sim.get('11101',0)/sample_shots)+(result_sim.get('11110',0)/sample_shots)
        P_1=(result_sim.get('00001',0)/sample_shots)+(result_sim.get('00010',0)/sample_shots)
        +(result_sim.get('00100',0)/sample_shots)+(result_sim.get('00111',0)/sample_shots)
        +(result_sim.get('01000',0)/sample_shots)+(result_sim.get('01011',0)/sample_shots)
        +(result_sim.get('01101',0)/sample_shots)+(result_sim.get('01110',0)/sample_shots)
        +(result_sim.get('10000',0)/sample_shots)+(result_sim.get('10011',0)/sample_shots)
        +(result_sim.get('10101',0)/sample_shots)+(result_sim.get('10110',0)/sample_shots)
        +(result_sim.get('11001',0)/sample_shots)+(result_sim.get('11010',0)/sample_shots)
        +(result_sim.get('11100',0)/sample_shots)+(result_sim.get('11111',0)/sample_shots)
        XXXXY = P_0-P_1
        return [XXXYY, XXXXX, XYYYY, XXYYY, YYYYY, XXXXY]
    
    Y = partial(params) 
    M5 = 4*(-Y[1] - 5*Y[2] + 10*Y[0])
    Mb5 = 4*(-Y[4] - 5*Y[5] + 10*Y[3])
    M5LR = 4
    M5ba = M5/M5LR
    Mb5ba = Mb5/M5LR
    print (M5)
    
    return [M5ba, Mb5ba]

# %%
import time
t0 = time.time()
time.sleep(1)
print('time cost: {}'.format(time.time() - t0))
# Out:
# time cost: 1.0012397766113281

# %%
num = 10
M5_list = []
Mb5_list = []
for i in range (num):
    X= expval(params)
    M5_list.append(X[0])
    Mb5_list.append(X[1])
    print (X)
# Out:
# 4.41015625
# [1.1025390625, 0.447265625]
# 4.48046875
# [1.1201171875, 0.4921875]
# 4.51953125
# [1.1298828125, 0.615234375]
# 4.3203125
# [1.080078125, 0.6015625]
# 5.25390625
# [1.3134765625, 0.697265625]
# 4.80859375
# [1.2021484375, 0.796875]
# 5.28125
# [1.3203125, 0.9091796875]
# 5.1171875
# [1.279296875, 0.50390625]
# 4.03125
# [1.0078125, 0.486328125]
# 4.58984375
# [1.1474609375, 0.6298828125]

# %%
#將list中的結果以excel匯出
dict = {'M5': M5_list, 'Mb5': Mb5_list}
df = pd.DataFrame(dict)
df.index = df.index+1
df.to_excel("output_5qubit.xlsx")
