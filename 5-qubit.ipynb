# %%
from qiskit import *
from qiskit import QuantumCircuit, assemble, Aer
from math import pi, sqrt, sin, cos
from qiskit.visualization import plot_bloch_multivector, plot_histogram
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os,sys
from collections import Counter
from collections import OrderedDict
from qiskit.quantum_info import Statevector

# %%
fi = 4*1/4*pi
q = QuantumRegister(5)
c = ClassicalRegister(5)
qc = QuantumCircuit(q,c)

qc.h(q[0])
qc.cx(q[0],q[1])
qc.cx(q[1],q[2])
qc.cx(q[2],q[3])
qc.cx(q[3],q[4])
qc.u(0, 0, fi, q[0])

qc.barrier(q)

#XXXYY    

qc.sdg(3)
qc.sdg(4)

qc.h(q[0])
qc.h(q[1])
qc.h(q[2])
qc.h(q[3])
qc.h(q[4])

qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])
qc.measure(q[3], c[3])
qc.measure(q[4], c[4])

backend1 = Aer.get_backend('qasm_simulator')
job1 = execute(qc, backend1, shots=1024)
result1 = job1.result()
count1 =result1.get_counts()
total1 = sum(count1.values(), 0.0)
count1 = {k: v / total1 for k, v in count1.items()}
qc.draw(output='mpl')
print(4*1/4,'pi',count1)
 #   plot_histogram(count1)
# Out:
# 1.0 pi {'00110': 0.0478515625, '10111': 0.0634765625, '10010': 0.052734375, '00011': 0.0673828125, '11011': 0.052734375, '01010': 0.072265625, '01001': 0.0595703125, '11101': 0.060546875, '11000': 0.0576171875, '01111': 0.0703125, '10100': 0.0625, '11110': 0.0634765625, '01100': 0.0693359375, '00101': 0.06640625, '10001': 0.06640625, '00000': 0.0673828125}

# %%
fi = 4*1/4*pi
q = QuantumRegister(5)
c = ClassicalRegister(5)
qc = QuantumCircuit(q,c)

qc.h(q[0])
qc.cx(q[0],q[1])
qc.cx(q[1],q[2])
qc.cx(q[2],q[3])
qc.cx(q[3],q[4])
qc.u(0, 0, fi, q[0])
qc.barrier(q)
#XXXXX
qc.h(q[0])
qc.h(q[1])
qc.h(q[2])
qc.h(q[3])
qc.h(q[4])

qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])
qc.measure(q[3], c[3])
qc.measure(q[4], c[4])

backend2 = Aer.get_backend('qasm_simulator')
job2 = execute(qc, backend2, shots=1024)
result2 = job2.result()
count2 =result2.get_counts()
total2 = sum(count2.values(), 0.0)
count2 = {k: v / total2 for k, v in count2.items()}
print(4*1/4,'pi',count2)
#    plot_histogram(count2)
qc.draw(output='mpl')
# Out:
# 1.0 pi {'11111': 0.056640625, '10110': 0.0595703125, '01011': 0.0771484375, '11100': 0.0771484375, '00010': 0.048828125, '00001': 0.0673828125, '11010': 0.0595703125, '00100': 0.0615234375, '01101': 0.0615234375, '00111': 0.052734375, '01110': 0.0625, '11001': 0.0595703125, '10000': 0.0751953125, '10101': 0.0556640625, '01000': 0.0673828125, '10011': 0.0576171875}

# %%
fi = 4*1/4*pi
q = QuantumRegister(5)
c = ClassicalRegister(5)
qc = QuantumCircuit(q,c)

qc.h(q[0])
qc.cx(q[0],q[1])
qc.cx(q[1],q[2])
qc.cx(q[2],q[3])
qc.cx(q[3],q[4])
qc.u(0, 0, fi, q[0])

qc.barrier(q)
    
#XYYYY
qc.sdg(1)
qc.sdg(2)
qc.sdg(3)
qc.sdg(4)
qc.h(q[0])
qc.h(q[1])
qc.h(q[2])
qc.h(q[3])
qc.h(q[4])

qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])
qc.measure(q[3], c[3])
qc.measure(q[4], c[4])

backend3 = Aer.get_backend('qasm_simulator')
job3 = execute(qc, backend3, shots=1024)
result3 = job3.result()
count3 =result3.get_counts()
total3 = sum(count3.values(), 0.0)
count3 = {k: v / total3 for k, v in count3.items()}
print(4*1/4,'pi',count3)
#    plot_histogram(count3)
qc.draw(output='mpl')
# Out:
# 1.0 pi {'11100': 0.064453125, '01011': 0.0732421875, '10011': 0.0693359375, '00010': 0.064453125, '01110': 0.0634765625, '11010': 0.0595703125, '01101': 0.0693359375, '00100': 0.0634765625, '01000': 0.076171875, '10101': 0.0712890625, '11001': 0.0595703125, '00111': 0.0458984375, '10110': 0.0576171875, '00001': 0.05859375, '10000': 0.0439453125, '11111': 0.0595703125}

# %%
fi = 4*1/4*pi
q = QuantumRegister(5)
c = ClassicalRegister(5)
qc = QuantumCircuit(q,c)

qc.h(q[0])
qc.cx(q[0],q[1])
qc.cx(q[1],q[2])
qc.cx(q[2],q[3])
qc.cx(q[3],q[4])
qc.u(0, 0, fi, q[0])

qc.barrier(q)

#XXYYY    
qc.sdg(2)
qc.sdg(3)
qc.sdg(4)

qc.h(q[0])
qc.h(q[1])
qc.h(q[2])
qc.h(q[3])
qc.h(q[4])

qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])
qc.measure(q[3], c[3])
qc.measure(q[4], c[4])

backend4 = Aer.get_backend('qasm_simulator')
job4 = execute(qc, backend4, shots=1024)
result4 = job4.result()
count4 =result4.get_counts()
total4 = sum(count4.values(), 0.0)
count4 = {k: v / total4 for k, v in count4.items()}
qc.draw(output='mpl')
print(4*1/4,'pi',count4)
 #   plot_histogram(count4)
# Out:
# 1.0 pi {'10000': 0.0322265625, '11000': 0.0341796875, '11001': 0.0224609375, '10001': 0.0322265625, '00000': 0.029296875, '00101': 0.0283203125, '11101': 0.029296875, '10110': 0.0302734375, '00110': 0.0400390625, '11110': 0.025390625, '00100': 0.033203125, '00011': 0.0263671875, '10011': 0.0361328125, '01011': 0.0322265625, '00111': 0.0400390625, '00001': 0.0390625, '01110': 0.037109375, '01100': 0.029296875, '11100': 0.03515625, '01111': 0.0302734375, '01010': 0.033203125, '00010': 0.029296875, '01000': 0.0322265625, '10100': 0.033203125, '10111': 0.0283203125, '01101': 0.03515625, '01001': 0.0205078125, '10101': 0.025390625, '11010': 0.03125, '11111': 0.0302734375, '11011': 0.0322265625, '10010': 0.0263671875}

# %%
fi = 4*1/4*pi
q = QuantumRegister(5)
c = ClassicalRegister(5)
qc = QuantumCircuit(q,c)

qc.h(q[0])
qc.cx(q[0],q[1])
qc.cx(q[1],q[2])
qc.cx(q[2],q[3])
qc.cx(q[3],q[4])
qc.u(0, 0, fi, q[0])

qc.barrier(q)

#YYYYY
qc.sdg(0)
qc.sdg(1)
qc.sdg(2)
qc.sdg(3)
qc.sdg(4)

qc.h(q[0])
qc.h(q[1])
qc.h(q[2])
qc.h(q[3])
qc.h(q[4])

qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])
qc.measure(q[3], c[3])
qc.measure(q[4], c[4])

backend5 = Aer.get_backend('qasm_simulator')
job5 = execute(qc, backend5, shots=1024)
result5 = job5.result()
count5 =result5.get_counts()
total5 = sum(count5.values(),0.0)
count5 = {k: v / total5 for k, v in count5.items()}
print(4*1/4,'pi',count5)
#    plot_histogram(count5)
qc.draw(output='mpl')
# Out:
# 1.0 pi {'11101': 0.0341796875, '01010': 0.0283203125, '01001': 0.029296875, '10110': 0.0302734375, '01011': 0.029296875, '11011': 0.03125, '01101': 0.033203125, '10001': 0.025390625, '00101': 0.033203125, '11110': 0.046875, '11100': 0.029296875, '10101': 0.025390625, '00000': 0.037109375, '10011': 0.0322265625, '11000': 0.0244140625, '00110': 0.03125, '11001': 0.02734375, '00100': 0.03515625, '10111': 0.033203125, '00111': 0.0322265625, '01111': 0.0244140625, '01000': 0.0400390625, '00001': 0.029296875, '10100': 0.0234375, '10000': 0.033203125, '11010': 0.033203125, '10010': 0.03125, '00010': 0.0380859375, '11111': 0.0234375, '00011': 0.03515625, '01100': 0.021484375, '01110': 0.0380859375}

# %%
fi = 4*1/4*pi
q = QuantumRegister(5)
c = ClassicalRegister(5)
qc = QuantumCircuit(q,c)

qc.h(q[0])
qc.cx(q[0],q[1])
qc.cx(q[1],q[2])
qc.cx(q[2],q[3])
qc.cx(q[3],q[4])
qc.u(0, 0, fi, q[0])

qc.barrier(q)

#XXXXY
qc.sdg(4)

qc.h(q[0])
qc.h(q[1])
qc.h(q[2])
qc.h(q[3])
qc.h(q[4])

qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])
qc.measure(q[3], c[3])
qc.measure(q[4], c[4])

backend6 = Aer.get_backend('qasm_simulator')
job6 = execute(qc, backend6, shots=1024)
result6 = job6.result()
count6 =result6.get_counts()
total6 = sum(count6.values(), 0.0)
count6 = {k: v / total6 for k, v in count6.items()}
print(4*1/4,'pi',count5)
#    plot_histogram(count5)
qc.draw(output='mpl')
# Out:
# 1.0 pi {'11101': 0.0341796875, '01010': 0.0283203125, '01001': 0.029296875, '10110': 0.0302734375, '01011': 0.029296875, '11011': 0.03125, '01101': 0.033203125, '10001': 0.025390625, '00101': 0.033203125, '11110': 0.046875, '11100': 0.029296875, '10101': 0.025390625, '00000': 0.037109375, '10011': 0.0322265625, '11000': 0.0244140625, '00110': 0.03125, '11001': 0.02734375, '00100': 0.03515625, '10111': 0.033203125, '00111': 0.0322265625, '01111': 0.0244140625, '01000': 0.0400390625, '00001': 0.029296875, '10100': 0.0234375, '10000': 0.033203125, '11010': 0.033203125, '10010': 0.03125, '00010': 0.0380859375, '11111': 0.0234375, '00011': 0.03515625, '01100': 0.021484375, '01110': 0.0380859375}

# %%
M5 = (-Counter(count2)
      -Counter(count3)-Counter(count3)-Counter(count3)-Counter(count3)-Counter(count3)
      +Counter(count1)+Counter(count1)+Counter(count1)+Counter(count1)+Counter(count1)
      +Counter(count1)+Counter(count1)+Counter(count1)+Counter(count1)+Counter(count1))
M5p = (Counter(count5)
       +Counter(count6)+Counter(count6)+Counter(count6)+Counter(count6)+Counter(count6)     
       -Counter(count4)-Counter(count4)-Counter(count4)-Counter(count4)-Counter(count4)
       -Counter(count4)-Counter(count4)-Counter(count4)-Counter(count4)-Counter(count4))
M5LR = 2**(5-1)
M5ba=(M5['00000']-M5['00001']-M5['00010']+M5['00011']-M5['00100']+M5['00101']
      +M5['00110']-M5['00111']-M5['01000']+M5['01001']+M5['01010']-M5['01011']
      +M5['01100']-M5['01101']-M5['01110']+M5['01111']-M5['10000']+M5['10001']
      +M5['10010']-M5['10011']+M5['10100']-M5['10101']-M5['10110']+M5['10111']
      +M5['11000']-M5['11001']-M5['11010']+M5['11011']-M5['11100']+M5['11101']
      +M5['11110']-M5['11111'])
M5pba=(M5p['00000']-M5p['00001']-M5p['00010']+M5p['00011']-M5p['00100']+M5p['00101']
      +M5p['00110']-M5p['00111']-M5p['01000']+M5p['01001']+M5p['01010']-M5p['01011']
      +M5p['01100']-M5p['01101']-M5p['01110']+M5p['01111']-M5p['10000']+M5p['10001']
      +M5p['10010']-M5p['10011']+M5p['10100']-M5p['10101']-M5p['10110']+M5p['10111']
      +M5p['11000']-M5p['11001']-M5p['11010']+M5p['11011']-M5p['11100']+M5p['11101']
      +M5p['11110']-M5p['11111'])
print (M5ba)
print (M5pba)
print (M5ba/M5LR)
print (M5pba/M5LR)
# Out:
# 10.0
# 0.0244140625
# 0.625
# 0.00152587890625
